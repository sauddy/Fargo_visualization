# %%
## This script is used to vizualise the data from the output of FARGO Simulations


# Author: sayantan
# Date : 20 March 2020

## This script imports the Fargo_class module for this implementation
## All the possible applications are demonstrated.

## importing the class module developed by Sayantan
import Fargo_visual_class as FV

# %%
################################### User defined inputs ##################
# folder ='/Volumes/My_Seagate/Training_set/TS_690_720/outputs/fargo_multifluid_new_692/'
# folder ='/Volumes/My_Seagate/Training_set/TS_1_50/outputs/fargo_multifluid_new_21/'
# folder ='/Volumes/My_Seagate/Training_set/TS_1_50/outputs/fargo_multifluid_new_0/'
folder ='/Volumes/My_Seagate/Training_set/TS_100_125/outputs/fargo_multifluid_new_119//'
# folder ='/Users/sayantan/Desktop/Programming/Dusty_Disk_Gap/Training_set/TS_690_720/outputs/fargo_multifluid_new_692/'
# folder =folder ='/Users/sayantan/Desktop/Programming/Dusty_Disk_Gap/Training_set/TS_690_720/'
fluid_list = ['gas','dust1']
fluid_property_list = ['dens','vy','vx']

#######please select the particular fluid and the field from the list##########
f=0;p=0
fluid = fluid_list[f]
fluid_property= fluid_property_list[p]
fraction = 0.5
V = FV.fargo_visualization(output_folder=folder)
# Out:
# Nx= 512 Ny= 512 alpha= 0.00947 epsilon= 0.0225 Planet Mass= 5.74e-05

# %%
V._density_plot(fluid,fluid_property,plot_type="2D_polar",output=None,fraction=fraction,ax=None)
# Out:
# currently plotting output=  150
# 0

# %%
# V._density_plot(fluid,fluid_property,plot_type="1D",output=None,fraction=fraction,ax=None)

# %%
V._get_the_disk_gap(fluid,fluid_property,fraction=fraction,output=None,gap_type="Dong",plot=True)
# Out:
# Using Dong Gap Formumla
# 0
# (array([0., 0.]), 0, array([0.]))

# %%
V._get_the_disk_gap(fluid,fluid_property,fraction=fraction,output=None,gap_type=None,plot=True)
# Out:
# 0
# (array([0., 0.]), 0, array([0.]))

# %%
V._time_evol_disk_gap(fluid,fluid_property,fraction=fraction,gap_type='Dong',frequency=10)
# Out:
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0
# Using Dong Gap Formumla
# 0

# %%
V._time_lapse(fluid_list[0],fluid_property,plot_type="2D_polar",gap_type="Dong", Parallel=None)
# Out:
# Dong
# 2D_polar
# Plotting now...
# currently plotting output=  0
# Using Dong Gap Formumla
# 0
# currently plotting output=  10
# Using Dong Gap Formumla
# 0
# currently plotting output=  20
# Using Dong Gap Formumla
# 0
# currently plotting output=  30
# Using Dong Gap Formumla
# 0
# currently plotting output=  40
# Using Dong Gap Formumla
# 0
# currently plotting output=  50
# Using Dong Gap Formumla
# 0
# currently plotting output=  60
# Using Dong Gap Formumla
# 0
# currently plotting output=  70
# Using Dong Gap Formumla
# 0
# currently plotting output=  80
# Using Dong Gap Formumla
# 0
# currently plotting output=  90
# Using Dong Gap Formumla
# 0
# currently plotting output=  100
# Using Dong Gap Formumla
# 0
# currently plotting output=  110
# Using Dong Gap Formumla
# 0
# currently plotting output=  120
# Using Dong Gap Formumla
# 0
# currently plotting output=  130
# Using Dong Gap Formumla
# 0
# currently plotting output=  140
# Using Dong Gap Formumla
# 0
# ...
